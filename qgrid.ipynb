# %% [markdown]
# # `qgrid`
#
# A pivot table style data manipulation tool, this one from the folks at Quantopian.

# %%
import qgrid

# %%
qgrid.nbinstall(overwrite=True)

# %%
import pandas as pd
pd.set_option("max_columns", 500)

# %%
sales = pd.read_csv("nyc_building_sales.csv", index_col=1)
# Out:
# C:\Users\Alex\Anaconda3\envs\dummy_env_3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (23,26,28,29,70,71,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sales.head(2)
# Out:
#        Unnamed: 0 Borough   Block   Lot  SalePrice  LandSquareFeet  \
# Index
# 0               0   Bronx  2268.0  18.0  1800000.0          2500.0
# 1               1   Bronx  2278.0  23.0   499000.0          1667.0
#
#        MarketValueSqFt     CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# Index
# 0           221.538462  201.0    41.0  1002.0         7.0      8.0  10454.0
# 1           215.086207  201.0    19.0  1010.0         7.0      8.0  10454.0
#
#       FireComp  PolicePrct  HealthArea  SanitBoro  SanitDistrict SanitSub  \
# Index
# 0         E083        40.0      4500.0        2.0            1.0       2A
# 1         E060        40.0      4700.0        2.0            1.0       1A
#
#                    Address ZoneDist1 ZoneDist2 ZoneDist3  ZoneDist4 Overlay1  \
# Index
# 0      532 EAST 142 STREET        R6       NaN       NaN        NaN      NaN
# 1      430 EAST 134 STREET  M1-2/R6A       NaN       NaN        NaN      NaN
#
# ...

# %%
qgrid.show_grid(sales.sample(100))

# %% [markdown]
# It might only work on time-series data. Stupid.
